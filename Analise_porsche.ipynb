# %% [markdown]
# Análise de dados sobre modelos de porcshe 911

# %%
import pandas as pd

# %%
df = pd.read_csv('DataSets/porsche_911.csv')
df.head()
# Out:
#                                                 link      generation   \
# 0  https://www.auto-data.net/en/porsche-911-dakar...  911 Dakar (992)
# 1  https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 2  https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 3  https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 4  https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
#
#                     engine  start_of_production      powertrain_architecture  \
# 0    3.0 (480 Hp) AWD PDK                  2022  Internal Combustion engine
# 1     4S 3.0 (450 Hp) PDK                  2020  Internal Combustion engine
# 2         4S 3.0 (450 Hp)                  2020  Internal Combustion engine
# 3  4 GTS 3.0 (480 Hp) PDK                  2021  Internal Combustion engine
# 4      4 GTS 3.0 (480 Hp)                  2021  Internal Combustion engine
#
#                   body_type seats  doors           fuel_type  \
# ...
